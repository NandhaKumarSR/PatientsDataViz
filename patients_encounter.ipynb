# %%
import pandas as pd

# %%
patients = pd.read_csv(r"C:\Users\Asus\Desktop\Hackathon Project\Files\Other Data\patients.csv")

# %%
patients.head()
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  c3b2e799-5291-dc30-dbfc-679181de00aa  1978-09-24       NaN  999-25-4120
# 1  dabfdec7-929a-3269-fd84-ab7e6ecaa245  1999-09-19       NaN  999-80-4324
# 2  a793a189-7e7f-48b6-ea63-43036cef8d3d  1997-06-01       NaN  999-96-4656
# 3  a08c883f-bdbd-7d0b-158d-17a69e78337b  1952-12-05       NaN  999-14-7102
# 4  6252ef78-e442-3081-f63b-36435c505a7f  1991-07-25       NaN  999-69-1046
#
#      DRIVERS    PASSPORT PREFIX      FIRST          LAST SUFFIX  ...  \
# 0  S99920883  X76703511X    Mr.   Riley817    Langosh790    NaN  ...
# 1  S99978853  X16410107X    Mr.   Adolph80  Bartoletti50    NaN  ...
# 2  S99930925  X74559429X    Mr.   Aubrey96      Kunde533    NaN  ...
# 3  S99913591  X27981597X    Mr.    Adán600     Delrío329    NaN  ...
# 4  S99936283  X26200534X    Mr.  Carter549       Haag279    NaN  ...
#
#          CITY       STATE               COUNTY    FIPS    ZIP        LAT  \
# ...

# %%
encounters = pd.read_csv(r"C:\Users\Asus\Desktop\Hackathon Project\Files\Other Data\encounters.csv")

# %%
encounters.head()
# Out:
#                                      Id                 START  \
# 0  8d3b00ea-681f-4f18-9e62-8d2ee98aae1a  1978-09-24T16:45:53Z
# 1  3d45be6c-b27f-c771-7bba-ccc85ed702ea  1978-10-29T16:45:53Z
# 2  43a466cb-d4b5-9e25-bc8c-123a09f13aa3  1978-12-31T16:45:53Z
# 3  5222266e-675d-56a2-44ce-5b52d3aa1b42  1979-12-02T16:45:53Z
# 4  c623c695-2884-6041-8e0a-d76ba2b88217  1981-03-01T16:45:53Z
#
#                    STOP                               PATIENT  \
# 0  1978-09-24T17:00:53Z  c3b2e799-5291-dc30-dbfc-679181de00aa
# 1  1978-10-29T17:00:53Z  c3b2e799-5291-dc30-dbfc-679181de00aa
# 2  1978-12-31T17:00:53Z  c3b2e799-5291-dc30-dbfc-679181de00aa
# 3  1979-12-02T17:00:53Z  c3b2e799-5291-dc30-dbfc-679181de00aa
# 4  1981-03-01T17:00:53Z  c3b2e799-5291-dc30-dbfc-679181de00aa
#
#                            ORGANIZATION                              PROVIDER  \
# 0  ccb5b561-e2b3-365c-a430-daeb9e4ea5eb  843403b7-6284-3663-9fd0-23f86dae397c
# ...

# %%
result = patients.merge(encounters, left_on='Id', right_on='PATIENT', how='left')

# %%
result.head()
# Out:
#                                    Id_x   BIRTHDATE DEATHDATE          SSN  \
# 0  c3b2e799-5291-dc30-dbfc-679181de00aa  1978-09-24       NaN  999-25-4120
# 1  c3b2e799-5291-dc30-dbfc-679181de00aa  1978-09-24       NaN  999-25-4120
# 2  c3b2e799-5291-dc30-dbfc-679181de00aa  1978-09-24       NaN  999-25-4120
# 3  c3b2e799-5291-dc30-dbfc-679181de00aa  1978-09-24       NaN  999-25-4120
# 4  c3b2e799-5291-dc30-dbfc-679181de00aa  1978-09-24       NaN  999-25-4120
#
#      DRIVERS    PASSPORT PREFIX     FIRST        LAST SUFFIX  ...  \
# 0  S99920883  X76703511X    Mr.  Riley817  Langosh790    NaN  ...
# 1  S99920883  X76703511X    Mr.  Riley817  Langosh790    NaN  ...
# 2  S99920883  X76703511X    Mr.  Riley817  Langosh790    NaN  ...
# 3  S99920883  X76703511X    Mr.  Riley817  Langosh790    NaN  ...
# 4  S99920883  X76703511X    Mr.  Riley817  Langosh790    NaN  ...
#
#                                PROVIDER                                 PAYER  \
# ...
